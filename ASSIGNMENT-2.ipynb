# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/House Price India.csv')
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df.shape
# Out:
# (14620, 23)

# %%
sns.countplot(data=df, x='number of bedrooms')
plt.title('Count of Number of Bedrooms')
plt.figure(figsize=(15,8))
plt.show()

# %%
sns.countplot(data=df, x='number of floors')
plt.title('Count of Number of Bedrooms')
plt.figure(figsize=(15,8))
plt.show()

# %%
sns.countplot(data=df, x='grade of the house')
plt.title('Count of Number of Bedrooms')
plt.figure(figsize=(15,8))
plt.show()

# %%
sns.displot(df['Price'])
plt.title('Price Distribution')
plt.show()

# %%
sns.histplot(data=df, x='Number of schools nearby')
plt.show()

# %%
sns.barplot(data=df,x='number of bedrooms',y='Price')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Price'>

# %%
sns.barplot(data=df, x='condition of the house', y='grade of the house')
# Out:
# <Axes: xlabel='condition of the house', ylabel='grade of the house'>

# %%
sns.barplot(data=df,x='number of bedrooms',y='number of floors')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='number of floors'>

# %%
sns.barplot(data=df,x='number of bedrooms',y='grade of the house')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='grade of the house'>

# %%
sns.barplot(data=df,x='number of bedrooms',y='condition of the house')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='condition of the house'>

# %%
df["house_age"] = df["Built Year"].max() - df["Built Year"]

# %%
df["renovated"] = df["Renovation Year"].apply(lambda x: 1 if x > 0 else 0)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x="house_age", y="Price", hue="renovated", data=df, alpha=0.5)
plt.show()

# %%
size_features = ["living area", "number of views", "number of bedrooms", "number of bathrooms", "living_area_renov", "Area of the house(excluding basement)", "grade of the house"]
sns.pairplot(df[size_features])
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),linewidths=0.5,annot=True,cmap='Blues')
plt.show()
