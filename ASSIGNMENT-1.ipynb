# %%
import numpy as np
import pandas as pd

# %% [markdown]
#  Task-1: Create a pandas dataframe (DataFrame name as 'df') with numpy random values (4 features and 4 observation)

# %%
data = np.random.rand(4, 4)
df = pd.DataFrame(data)
df
# Out:
#           0         1         2         3
# 0  0.642944  0.124853  0.310617  0.477998
# 1  0.083071  0.198933  0.224923  0.574886
# 2  0.052797  0.964762  0.368655  0.891865
# 3  0.467292  0.874867  0.289091  0.733829

# %% [markdown]
# Task-2: Rename the task - 1 'df' dataframe column names to 'Random value 1', 'Random value 2', 'Random value 3' & 'Random value 4'

# %%
df.columns = ['Random Value 1', 'Random Value 2', 'Random Value 3', 'Random Value 4']
df
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0        0.642944        0.124853        0.310617        0.477998
# 1        0.083071        0.198933        0.224923        0.574886
# 2        0.052797        0.964762        0.368655        0.891865
# 3        0.467292        0.874867        0.289091        0.733829

# %% [markdown]
# Task-3: Find the descriptive statistics of the 'df' dataframe.

# %%
df.describe()
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.311526        0.540854        0.298322        0.669644
# std          0.290536        0.440163        0.059359        0.181851
# min          0.052797        0.124853        0.224923        0.477998
# 25%          0.075502        0.180413        0.273049        0.550664
# 50%          0.275181        0.536900        0.299854        0.654357
# 75%          0.511205        0.897341        0.325126        0.773338
# max          0.642944        0.964762        0.368655        0.891865

# %% [markdown]
# Task-4: Check for the null values in 'df' and find the data type of the columns.

# %%
df.isnull().sum()
# Out:
# Random Value 1    0
# Random Value 2    0
# Random Value 3    0
# Random Value 4    0
# dtype: int64

# %%
df.dtypes
# Out:
# Random Value 1    float64
# Random Value 2    float64
# Random Value 3    float64
# Random Value 4    float64
# dtype: object

# %% [markdown]
# Task-5: Display the 'Random value 2' & 'Random value 3' columns with location method and index location method.

# %%
df.iloc[:, 1]
# Out:
# 0    0.124853
# 1    0.198933
# 2    0.964762
# 3    0.874867
# Name: Random Value 2, dtype: float64

# %%
df.iloc[:, 2]
# Out:
# 0    0.310617
# 1    0.224923
# 2    0.368655
# 3    0.289091
# Name: Random Value 3, dtype: float64

# %%
print(df['Random Value 2'])
print(df['Random Value 3'])
# Out:
# 0    0.124853
# 1    0.198933
# 2    0.964762
# 3    0.874867
# Name: Random Value 2, dtype: float64
# 0    0.310617
# 1    0.224923
# 2    0.368655
# 3    0.289091
# Name: Random Value 3, dtype: float64
